# %%
import matplotlib.pyplot as plt 
import matplotlib.image as img
import matplotlib.gridspec as gridspec
from matplotlib.patches import Rectangle
from matplotlib.patches import ConnectionPatch
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import numpy as np
import richardsplot
import os
# Out:
# /Users/trevormccaffrey/anaconda3/lib/python3.6/_collections_abc.py:841: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   self[key] = other[key]

# %%
#Values stored manually in 
#"/Users/trevormccaffrey/Desktop/Research/RQQSOs_AmyKimball/contour_props.txt"

#Store image props in dictionary - easy then to call in plotting
#Index 0 of tuple is linear size in kpc;
#Index 1 of tuple is the value of the base contour in µJy
#Index 2 of tuple tells where to put the inset box in the A-config image
FIRST   = 0
Cconfig = 1
VLASS   = 2
Aconfig = 3
YearQ   = 4
YearI   = 3


imgsRQ = {
    "0856+1057": (105, 170, 60, 15, [2000,2011,2018,2019]),
    "1000+1047": (105, 90, 55, 13, [2000,2011,2017,2019])
}

imgsRI = {
    "1017+1516": (177, 193, 92, [1999,2011,2017]),
    "1511+1009": (196, 213, 102, [2000,2011,2019]),
    "1513+2623": (153, 167, 80, [1995,2011,2017])
}

# %%
path = "first_vlass_cutouts/"

for obj in imgsRQ:
    if not obj.startswith("."): #ignore hidden files/directories
        fig, [ax0, ax1, ax2, ax3] = plt.subplots(1, 4, figsize=(30,7))
        
        #Show the FIRST image
        imF = img.imread(path+obj+"/{}_FIRST.png".format(obj))
        ax0.imshow(imF)
        #ax0.annotate("J"+obj, xy=(20, 100), xytext=(0, 0), textcoords='offset points', 
        #             color="#15ff00", fontsize=62.5)
        
        ax0.annotate('', xy=(140, 575), xytext=(275, 0), textcoords='offset points', 
                        arrowprops=dict(arrowstyle="<|-|>, head_width=0.7, head_length=0.9",
                                       linewidth=3.5, color="w"))
        #ax0.annotate(str(round(0.6*imgsRQ[obj][FIRST]))+" kpc", xy=(240, 545), xytext=(0, 0), 
        #             textcoords='offset points', fontsize=50, color="w")
        #ax0.annotate("1.4 GHz", xy=(20, 180), fontsize=50, color="w",
        #                          xytext=(0, 0), textcoords='offset points')
        #ax0.annotate(str(imgsRQ[obj][YearQ][FIRST]), xy=(20, 265), fontsize=50, color="w",
        #                          xytext=(0, 0), textcoords='offset points')
        
        #Show the C-config image
        imC = img.imread(path+obj+"/{}_C.png".format(obj))
        ax1.imshow(imC)
        
        ax1.annotate('', xy=(140, 575), xytext=(275, 0), textcoords='offset points', 
                        arrowprops=dict(arrowstyle="<|-|>, head_width=0.7, head_length=0.9",
                                       linewidth=3.5, color="w"))
        #ax1.annotate(str(round(0.6*imgsRQ[obj][Cconfig]))+" kpc", xy=(240, 545), xytext=(0, 0), 
        #             textcoords='offset points', fontsize=50, color="w") 
        #ax1.annotate("6 GHz", xy=(430, 85), fontsize=50, color="w",
        #                          xytext=(0, 0), textcoords='offset points')
        #ax1.annotate(str(imgsRQ[obj][YearQ][Cconfig]), xy=(485, 160), fontsize=50, color="w",
        #                          xytext=(0, 0), textcoords='offset points')
        
        #Show the VLASS image       
        imV = img.imread(path+obj+"/{}_VLASS.png".format(obj))
        ax2.imshow(imV)
        #ax2.annotate("3 GHz", xy=(430, 85), fontsize=50, color="w",
        #                          xytext=(0, 0), textcoords='offset points')
            
        ax2.annotate('', xy=(140, 575), xytext=(275, 0), textcoords='offset points', 
                        arrowprops=dict(arrowstyle="<|-|>, head_width=0.7, head_length=0.9",
                                       linewidth=3.5, color="w"))
        #ax2.annotate(str(round(0.6*imgsRQ[obj][VLASS]))+" kpc", xy=(250, 545), xytext=(0, 0), 
        #             textcoords='offset points', fontsize=50, color="w") 
        #ax2.annotate(str(imgsRQ[obj][YearQ][VLASS]), xy=(485, 160), fontsize=50, color="w",
        #                          xytext=(0, 0), textcoords='offset points')
        
        
        #Show the A-config image
        imA = img.imread(path+obj+"/{}_A.png".format(obj))
        ax3.imshow(imA)
        
        ax3.annotate('', xy=(140, 575), xytext=(275, 0), textcoords='offset points', 
                        arrowprops=dict(arrowstyle="<|-|>, head_width=0.7, head_length=0.9",
                                       linewidth=3.5, color="w"))
        #ax3.annotate(str(round(0.6*imgsRQ[obj][Aconfig]))+" kpc", xy=(260, 545), xytext=(0, 0), 
        #             textcoords='offset points', fontsize=50, color="w") 
        #ax3.annotate("6 GHz", xy=(430, 85), fontsize=50, color="w",
        #                          xytext=(0, 0), textcoords='offset points')
        #ax3.annotate(str(imgsRQ[obj][YearQ][Aconfig]), xy=(485, 160), fontsize=50, color="w",
        #                          xytext=(0, 0), textcoords='offset points')
                
        ax0.axis("off")
        ax1.axis("off")
        ax2.axis("off")
        ax3.axis("off")
        plt.subplots_adjust(left=0.05, right=0.9, bottom=0.2, top=0.8)
        plt.tight_layout()
        plt.savefig("PaperPlots/{}_triptych_notext.pdf".format(obj), bbox_inches = 'tight', pad_inches = 0)
        plt.show()

# %%
path = "first_vlass_cutouts/intermediates/"

for obj in imgsRI:
    if not obj.startswith("."): #ignore hidden files/directories
        fig, [ax0, ax1, ax2] = plt.subplots(1, 3, figsize=(22.5,7))
        
        #Show the FIRST image
        imF = img.imread(path+obj+"/{}_FIRST.png".format(obj))
        ax0.imshow(imF)
        #ax0.annotate("J"+obj, xy=(20, 100), xytext=(0, 0), textcoords='offset points', 
        #             color="#15ff00", fontsize=62.5)
        
        ax0.annotate('', xy=(140, 575), xytext=(275, 0), textcoords='offset points', 
                        arrowprops=dict(arrowstyle="<|-|>, head_width=0.7, head_length=0.9",
                                       linewidth=3.5, color="w"))
        #ax0.annotate(str(round(0.6*imgsRI[obj][FIRST]))+" kpc", xy=(240, 545), xytext=(0, 0), 
        #             textcoords='offset points', fontsize=50, color="w")
        #ax0.annotate("1.4 GHz", xy=(20, 180), fontsize=50, color="w",
        #                          xytext=(0, 0), textcoords='offset points')
        #ax0.annotate(str(imgsRI[obj][YearI][FIRST]), xy=(20, 265), fontsize=50, color="w",
        #                          xytext=(0, 0), textcoords='offset points')
        
        #Show the C-config image
        imC = img.imread(path+obj+"/{}_C.png".format(obj))
        ax1.imshow(imC)
        
        ax1.annotate('', xy=(140, 575), xytext=(275, 0), textcoords='offset points', 
                        arrowprops=dict(arrowstyle="<|-|>, head_width=0.7, head_length=0.9",
                                       linewidth=3.5, color="w"))
        #ax1.annotate(str(round(0.6*imgsRI[obj][Cconfig]))+" kpc", xy=(240, 545), xytext=(0, 0), 
        #             textcoords='offset points', fontsize=50, color="w") 
        #ax1.annotate("6 GHz", xy=(430, 85), fontsize=50, color="w",
        #                          xytext=(0, 0), textcoords='offset points')
        #ax1.annotate(str(imgsRI[obj][YearI][Cconfig]), xy=(485, 160), fontsize=50, color="w",
        #                          xytext=(0, 0), textcoords='offset points')
        
        #Show the VLASS image       
        imV = img.imread(path+obj+"/{}_VLASS.png".format(obj))
        ax2.imshow(imV)
        #ax2.annotate("3 GHz", xy=(430, 85), fontsize=50, color="w",
        #                          xytext=(0, 0), textcoords='offset points')
            
        ax2.annotate('', xy=(140, 575), xytext=(275, 0), textcoords='offset points', 
                        arrowprops=dict(arrowstyle="<|-|>, head_width=0.7, head_length=0.9",
                                       linewidth=3.5, color="w"))
        #ax2.annotate(str(round(0.6*imgsRI[obj][VLASS]))+" kpc", xy=(240, 545), xytext=(0, 0), 
        #             textcoords='offset points', fontsize=50, color="w") 
        #ax2.annotate(str(imgsRI[obj][YearI][VLASS]), xy=(465, 160), fontsize=50, color="w",
        #                          xytext=(0, 0), textcoords='offset points')
        
                        
        ax0.axis("off")
        ax1.axis("off")
        ax2.axis("off")
        ax3.axis("off")
        plt.subplots_adjust(left=0.05, right=0.9, bottom=0.2, top=0.8)
        plt.tight_layout()
        plt.savefig("PaperPlots/{}_triptych_notext.pdf".format(obj), bbox_inches = 'tight', pad_inches = 0)
        plt.show()
