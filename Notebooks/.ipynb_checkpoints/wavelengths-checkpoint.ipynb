# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from astropy.io import fits

# %%
dat = pd.read_csv("../data/ParentSample_DR7props.csv")
dat.head()
# Out:
#             SDSS_NAME          RA        DEC  REDSHIFT  PLATE  FIBER    MJD  \
# 0  075403.60+481428.0  118.515030  48.241127    0.2755   1779    238  53089
# 1  080829.17+440754.1  122.121544  44.131702    0.2754    439    215  51877
# 2  081652.24+425829.4  124.217705  42.974842    0.2345    546    573  52205
# 3  082205.24+455349.1  125.521843  45.896980    0.2998    441     21  51868
# 4  083353.88+422401.8  128.474503  42.400528    0.2491    761    616  52266
#
#    TARGET_FLAG_TARGET  NSPECOBS  UNIFORM_TARGET  ...     pmp    f_c   logL  \
# 0                  11         1               1  ...    84.8  1.000  23.76
# 1                   5         1               0  ...    11.2  1.000  22.12
# 2                   4         3               0  ...    13.9  1.000  22.54
# 3                   4         1               0  ...    11.2  1.000  22.77
# 4           134225419         2               1  ...  6270.1  1.000  25.56
#
#       i_2   I_2a       R         LD_cm       Lobs   L_1.4GHz  SFR (Msun/yr)
# 0  17.148 -23.06    5.24  4.353706e+27  23.797049  24.313561    1214.542210
# 1  17.615 -22.58    0.19  4.335641e+27  22.158646  22.674920      27.910762
# 2  16.636 -23.21    0.29  3.608002e+27  22.579231  23.085568      71.848913
# 3  17.695 -22.69    0.73  4.791681e+27  22.806539  23.328715     125.767176
# 4  16.480 -23.50  224.98  3.871229e+27  25.595054  26.105064   75147.716658
#
# [5 rows x 161 columns]

# %%
sdss_names = dat[["SDSS_NAME"]].values.flatten()
z          = dat[["REDSHIFT"]].values.flatten()
plate      = dat[["PLATE"]].values.flatten()
mjd        = dat[["MJD"]].values.flatten()
fiber      = dat[["FIBER"]].values.flatten()

# %%
min(z), max(z)
# Out:
# (0.200900003314018, 0.299800008535385)

# %%
N=0

for red, pl, mj, fib in zip(z, plate, mjd, fiber):
    try:
        hdul_spec = fits.open("../data/spectra/kimballsample_full/%04d/spec-%04d-%05d-%04d.fits" % (pl,pl,mj,fib))
    except FileNotFoundError:
        print("../data/spectra/kimballsample_full/%04d/spec-%04d-%05d-%04d.fits NOT FOUND" % (pl,pl,mj,fib))
        continue
    #Load in data from each FITS file
    sdss_flux   = hdul_spec[1].data["flux"]
    sdss_loglam = hdul_spec[1].data["loglam"]
    sdss_wave   = 10.**(sdss_loglam) #/ (1+red)  #x-axis: wavelength
    sdss_ivar   = hdul_spec[1].data["ivar"]
    #wavemask   = ((sdss_wave>=1443) & (sdss_wave<=2961))
    print(min(sdss_wave), max(sdss_wave), round(red,2))
    #print(min(sdss_wave[wavemask]), max(sdss_wave[wavemask]), len(sdss_wave[wavemask]))
    N+=1
    if N>30: break
# Out:
# 3802.77 9181.21 0.28
# 3802.77 9189.672 0.28
# 3814.169 9208.736 0.23
# 3808.9043 9204.495 0.3
# 3819.4429 9202.379 0.25
# 3814.169 9193.905 0.29
# 3801.0188 9208.736 0.25
# 3795.7703 9189.672 0.22
# 3823.8423 9185.439 0.23
# 3794.0225 9189.672 0.28
# 3806.2727 9215.098 0.28
# 3815.0483 9183.327 0.27
# 3799.2686 9206.613 0.26
# 3797.519 9208.736 0.2
# 3798.3948 9191.785 0.22
# 3808.9043 9215.098 0.27
# 3815.0483 9217.223 0.2
# 3808.9043 9198.141 0.21
# 3801.8933 9193.905 0.29
# 3810.659 9221.464 0.3
# 3822.0815 9206.613 0.24
# 3805.3972 9198.141 0.24
# 3819.4429 9183.327 0.27
# 3795.7703 9196.0205 0.3
# 3815.0483 9215.098 0.22
# 3801.0188 9210.8545 0.23
# 3808.9043 9196.0205 0.25
# 3812.4126 9179.099 0.21
# 3809.7805 9215.098 0.28
# 3787.912 9189.672 0.27
# 3813.2917 9196.0205 0.23

# %% [markdown]
# Will train on $z<0.59$ QSOs from DR7.
